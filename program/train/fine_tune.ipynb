# %%
from ultralytics import YOLO
import torch
def main():
    
    print("CUDA:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("GPU:", torch.cuda.get_device_name(0))
        
    model = YOLO(
        r"C:\Users\kepin\runs\detect\predict_detect\fine_ture_2\weights\best.pt"
    )

    results = model.train(
        data=r"D:\license_plate_and_car_detection\dataset_15\data.yaml",
        epochs=75,
        imgsz=640,
        batch=16,
        device=0,
        workers=8,
        save=True,
        project="predict_detect",
        name="fine_ture_3",
        patience=50
    )

if __name__ == "__main__":
    main()
# Out:
# CUDA: True
# GPU: NVIDIA GeForce RTX 3060
# New https://pypi.org/project/ultralytics/8.4.116 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14  Python-3.10.20 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060, 8192MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights\best.pt"
)

# Export เป็น ONNX
model.export(
    format="onnx",
    imgsz=640,
    opset=12,
    simplify=True,
    dynamic=False
)
# Out:
# Ultralytics 8.4.14  Python-3.10.20 torch-2.5.1 CPU (12th Gen Intel Core i5-12400F)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 12...
# ONNX: slimming with onnxslim 0.1.95...
# ONNX: export success  5.5s, saved as 'C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights\best.onnx' (10.1 MB)
#
# Export complete (6.1s)
# Results saved to C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights
# Predict:         yolo predict task=detect model=C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=C:\Users\kepin\runs\detect\predict_detect\fine_ture_3\weights\best.onnx imgsz=640 data=D:\license_plate_and_car_detection\dataset_15\data.yaml
# ...
