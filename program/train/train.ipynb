# %%
import torch

print("torch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.5.1
# CUDA: True
# GPU: NVIDIA GeForce RTX 3060

# %%
from ultralytics import YOLO
import torch

# ตรวจสอบ GPU
print("CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# โหลดโมเดล
model = YOLO("yolo11n.pt")

# เทรน
results = model.train(
    data=r"D:\license_plate_and_car_detection\dataset\License_Plate\data.yaml",

    # Training
    epochs=200,
    imgsz=960,
    batch=16,

    # GPU
    device=0,

    # DataLoader
    workers=8,

    # Output
    project="models",
    name="plate_yolo11n_v1_for_detect",
    exist_ok=True,

    # Save
    save=True,
    save_period=10,

    # Optimization
    optimizer="auto",
    lr0=0.01,

    # Augmentation
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,

    degrees=5,
    translate=0.1,
    scale=0.3,

    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,

    # Validation
    val=True,
    plots=True,

    # Reproducibility
    seed=42
)
# Out:
# CUDA: True
# GPU: NVIDIA GeForce RTX 3060
# New https://pypi.org/project/ultralytics/8.4.78 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14  Python-3.10.20 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\license_plate_and_car_detection\dataset\License_Plate\data.yaml, degrees=5, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=plate_yolo11n_v1_for_detect, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=models, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\kepin\runs\detect\models\plate_yolo11n_v1_for_detect, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.3, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 7.614.0 MB/s, size: 54.1 KB)
# train: Scanning D:\license_plate_and_car_detection\dataset\License_Plate\train\labels... 1944 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1944/1944 95.2it/s 20.4ss<0.0s
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_123945_jpg.rf.e5oRHXYOWD8bdxLkAfMT.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124024_jpg.rf.ZRP2c7AZC9LhmGCduE5o.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124057_jpg.rf.TZ89jQCMbeAPHV9Fhoee.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124116_jpg.rf.P4rhdMtXU5yilaPdjxfO.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124314_jpg.rf.QNyF303c864DsI1howHz.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124433_jpg.rf.KkMiUbxVsu7IjevhfC7K.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124448_jpg.rf.dqzewfMEW6CiP2N6A7X7.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124548_jpg.rf.QqW2YXx8RvcKrYUtpI3O.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124615_jpg.rf.15ICvjBZajwyl3DjNWCS.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20220713_124734_jpg.rf.FTO9LxjGxnJKyUvwGZLT.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_184724_jpg.rf.1mYiN7iS3oKlbeelTMmh.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_185110_jpg.rf.bbHfp2Xr4b35wVfHTcK4.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_235044_jpg.rf.NVlY2acf2AMCawSbhHfV.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_235745_jpg.rf.6xtpygXikVWMrsixr8lB.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_235801_jpg.rf.H2Ld2bw17zvF4JMsqAyz.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221127_235917_jpg.rf.9ASsDPMtl3U0rGjW8IRO.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_122101_jpg.rf.r5gyfYDC4GzyyrmzrIOb.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_122645_jpg.rf.cXpxpa2jpBJE1sKp3BFv.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_172629_jpg.rf.IR54JTplbib8jtb0xyDA.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_172756_jpg.rf.ltFcjuq377pZZxpwsiA9.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_172808_jpg.rf.5J1MXvPPcBnU0ZLrNYlv.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221128_172833_jpg.rf.ROea08xtAzoztWvkvDho.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160036_jpg.rf.RO2eKfWIdyccOTepDPo7.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160225_jpg.rf.DafVL88Dbm8YQGXXs3CL.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160454_jpg.rf.YJ4AxcauoKP0eLeJMu4J.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160510_jpg.rf.zJC3FZqMAnKQD5Wxjh1d.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160612_jpg.rf.LDHx2yXYIatar7ARtyzo.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160634_jpg.rf.5BExcVJnSNGjyxUBIsSy.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160636_jpg.rf.Kcz4xqM1qgaeMi2tEFd5.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160733_jpg.rf.nxW7qshZsxb7YNPCcen1.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160811_jpg.rf.0rt67ecsU9foXVcPEbcn.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160823_jpg.rf.eV7QMpOUbibfu2eN6isB.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160936_jpg.rf.rZaQPknCsevNy0zayid0.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_160949_jpg.rf.ZnHo80QpcHjgP0AUJ61F.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161148_jpg.rf.pCgysLHkd2aepyoL5vF5.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161232_jpg.rf.xWw9Pn1txp8CbEx6lbzo.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161419_jpg.rf.BOCZePdxvjsHPnXpGny8.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161426_jpg.rf.1b4iIxvJoocPSU7fEcn2.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161700_jpg.rf.yjttfQNEedUggb8EECXw.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_161723_jpg.rf.8PI93cKse2khos3satTT.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221202_162942_jpg.rf.HOdw3ub1ArqDQdFwfO0e.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221212_171206_jpg.rf.84UXJPEPZNUSdzndUAkV.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221212_183802_jpg.rf.Ibrd8I7NYtwgqho2XVXv.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221212_183806_jpg.rf.5VXZxGXmNMbkvvy7YfNQ.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221212_183823_jpg.rf.p59BfngTBZWhNCVVZl48.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\20221212_183839_jpg.rf.tRsYxleO9pc6BFEkJast.jpg: corrupt JPEG restored and saved
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\Screenshot 2022-11-08 092114_png_png.rf.JaNIYBh1s40NJBul1zn0.png: 1 duplicate labels removed
# train: D:\license_plate_and_car_detection\dataset\License_Plate\train\images\WeChat Image_20220716104034_jpg.rf.rExLoAPEKw8njVoS1jmC.jpg: corrupt JPEG restored and saved
# train: New cache created: D:\license_plate_and_car_detection\dataset\License_Plate\train\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 16, len(boxes) = 2056. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.20.2 ms, read: 8.312.4 MB/s, size: 716.8 KB)
# val: Scanning D:\license_plate_and_car_detection\dataset\License_Plate\valid\labels... 322 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 322/322 53.2it/s 6.1s<0.5s
# val: D:\license_plate_and_car_detection\dataset\License_Plate\valid\images\20221127_184559_jpg.rf.oZIQYVWF4Ay06H8ka0WJ.jpg: corrupt JPEG restored and saved
# val: D:\license_plate_and_car_detection\dataset\License_Plate\valid\images\20221128_172618_jpg.rf.rujsA4k4YubuPbHnSGKK.jpg: corrupt JPEG restored and saved
# val: D:\license_plate_and_car_detection\dataset\License_Plate\valid\images\20221202_160234_jpg.rf.ARx3nktR0YMXho2aNsks.jpg: corrupt JPEG restored and saved
# val: D:\license_plate_and_car_detection\dataset\License_Plate\valid\images\20221202_160952_jpg.rf.ngBEWP26BLqNu1U1ty0b.jpg: corrupt JPEG restored and saved
# val: D:\license_plate_and_car_detection\dataset\License_Plate\valid\images\20221202_161518_jpg.rf.XuvmWmE9oP0bwfc5a1BN.jpg: corrupt JPEG restored and saved
# val: New cache created: D:\license_plate_and_car_detection\dataset\License_Plate\valid\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 349. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
